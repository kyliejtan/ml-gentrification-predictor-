# %% [markdown]
# ## Importing dependencies and environmental variables

# %%
# Dependencies
import csv as csv
import http.client 
import json
import numpy as np
import os
import pandas as pd
import pprint
import psycopg2
import requests
import sqlalchemy
from bs4 import BeautifulSoup as bs
from dotenv import load_dotenv
from selenium import webdriver
from sodapy import Socrata
from splinter import Browser
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, Float, Date
from time import sleep

# %%
# Loading homeowrk7.env so that the environment variables can be used in the engine object url
load_dotenv("project3.env")
# Initializing variables to hold each environmet varaible
username=os.environ.get("USERNAME")
password=os.environ.get("PASSWORD")
host=os.environ.get("HOST")
port=os.environ.get("PORT")
database=os.environ.get("DATABASE")
google_key = os.environ.get('GOOGLE_API_KEY')
yelp_client_id = os.environ.get('YELP_CLIENT_ID')
yelp_key = os.environ.get('YELP_API_KEY')
sf_data_key = os.environ.get('SFDATAAPPTOKEN')
acs_5yr_key = os.environ.get('ACS_5YR_KEY')

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Flask app Heroku DB connection stuff

# %%
app = Flask(__name__)

uri = os.environ.get("URI")
print(uri)
app.config["SQLALCHEMY_DATABASE_URI"] = 'postgres://gaoafzhoycjoin:3e7bfe74080d2238fa6ef14ee67e403af421b3d7d5cb45f12aa5df5fdbf1968b@ec2-174-129-43-40.compute-1.amazonaws.com:5432/dfu7vggjmve1rn'
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
# # Binding the instance of flask_sqlalchemy.SQLAlchemy to this specific flask app
db = SQLAlchemy(app)
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(db.engine, reflect=True)
# Initializing a variable with the created engine
engine = db.engine
# Initializing a variable with the connection resource
connection = engine.connect()
# Create our session (link) from Python to the DB
session = Session(engine)
inspector = inspect(engine)

# %% [markdown]
# ## Test querying the ACS 5-year API

# %%
# Initializing a variable for the total population of the query zip code
total_pop = "B01001_001E"
# Initializing variables to hold the numbers of females aged 24-34, and white females aged 24-34
total_24_29_female = "B01001_035E"
total_30_34_female = "B01001_036E"
total_24_29_female_wht = "B01001A_024E"
total_30_34_female_wht = "B01001A_025E"
# Initializing variables to hold the numbers of males aged 24-34, and white males aged 24-34
total_24_29_male = "B01001_011E"
total_30_34_male = "B01001_012E"
total_24_29_male_wht = "B01001A_009E"
total_30_34_male_wht = "B01001A_010E"
#
total_wht = "B01001A_001E"
# Initializing variables to hold the numbers of college degree-holders living in the query zip code
with_bachelors = "B06009_005E"
with_advanced_deg = "B06009_006E"
# Concatenating all of the above variables into a query string
variables = (total_pop 
             + "," + total_24_29_female 
             + "," + total_30_34_female 
             + "," + total_24_29_male 
             + "," + total_30_34_male 
             + "," + total_24_29_female_wht 
             + "," + total_30_34_female_wht 
             + "," + total_24_29_male_wht 
             + "," + total_30_34_male_wht 
             + "," + total_wht
             + "," + with_bachelors 
             + "," + with_advanced_deg)

# %%
# Initializing a test zip code
test_zip_code = 90001

# %%
# Initializing varibales to hold the base url and the complete query url
base_url = f"https://api.census.gov/data/2011/acs/acs5?get="
test_query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{test_zip_code}&key={acs_5yr_key}"

# %%
base_url = f"https://api.census.gov/data/2011/acs/acs5?get="
test_query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{test_zip_code}&key={acs_5yr_key}"

# %%
# Test printing the query url
test_query_url
# Out:
# 'https://api.census.gov/data/2011/acs/acs5?get=B01001_001E,B01001_035E,B01001_036E,B01001_011E,B01001_012E,B01001A_024E,B01001A_025E,B01001A_009E,B01001A_010E,B01001A_001E,B06009_005E,B06009_006E&for=zip%20code%20tabulation%20area:90001&key=13b3982d9633362d045587e957d3c1829384bce0'

# %%
# Querying the ACS 5-year API
acs_response = requests.get(test_query_url).json()

# %%
# Printing the query results for the test zip code
acs_response
# Out:
# [['B01001_001E',
#   'B01001_035E',
#   'B01001_036E',
#   'B01001_011E',
#   'B01001_012E',
#   'B01001A_024E',
#   'B01001A_025E',
#   'B01001A_009E',
#   'B01001A_010E',
#   'B01001A_001E',
#   'B06009_005E',
#   'B06009_006E',
#   'zip code tabulation area'],
#  ['54760',
#   '1971',
#   '2193',
#   '3144',
#   '2000',
#   '1608',
#   '1805',
#   '2353',
#   '1570',
#   '40379',
#   '912',
#   '278',
#   '90001']]

# %%
# Loading the query results into a DataFrame with updated column names
test_acs_df = pd.DataFrame(acs_response[1:], columns=[
                                                      "total_pop",
                                                      "total_24_29_female", 
                                                      "total_30_34_female", 
                                                      "total_24_29_male",
                                                      "total_30_34_male",
                                                      "total_24_29_female_wht",
                                                      "total_30_34_female_wht",
                                                      "total_24_29_male_wht",
                                                      "total_30_34_male_wht",
                                                      "total_wht",
                                                      "with_bachelors",
                                                      "with_advanced_deg",
                                                      "zip_code"
                                                     ])
cols = test_acs_df.columns.tolist()
cols = cols[-1:] + cols[:-1]
test_acs_df = test_acs_df[cols]

# %%
# Creating calculated columns for percent of zip code population aged 25-34, percent white, 
# and percent with a college degree
test_acs_df["pct_25_34"] = ((int(test_acs_df["total_24_29_female"])
                            + int(test_acs_df["total_30_34_female"]) 
                            + int(test_acs_df["total_24_29_male"])
                            + int(test_acs_df["total_30_34_female"]))
                            / int(test_acs_df["total_pop"])
                           ) * 100
test_acs_df["pct_college_deg"] = ((int(test_acs_df["with_bachelors"]) 
                                  + int(test_acs_df["with_advanced_deg"]))
                                  / int(test_acs_df["total_pop"])
                                 ) * 100
test_acs_df["pct_wht"] = (int(test_acs_df["total_wht"]) / int(test_acs_df["total_pop"])) * 100

# %%
# Displaying the DataFrame of test results
test_acs_df

# %% [markdown]
# ## Initializing variables with lists of all zip codes

# %%
# Initializing a variable with a list of all of the zipcodes in San Francisco
sf_zip_codes = [94102, 94103, 94104, 94105, 94107, 94108, 94109, 94110, 94111, 94112, 94114, 94115, 94116, 94117, 
               94118, 94121, 94122, 94123, 94124, 94127, 94129, 94130, 94131, 94132, 94133, 94134, 94158]

# %%
seattle_zip_codes = [98101, 98102, 98103, 98104, 98105, 98106, 98107, 98108, 98109, 98112, 98115, 98116, 98117, 
                     98118, 98119, 98121, 98122, 98124, 98125, 98126, 98133, 98134, 98136, 98144, 98146]

# %%
la_zip_codes = [90001, 90004, 90007, 90010, 90012, 90013, 90014, 90015, 90016, 90017, 90018, 90019, 90020, 90021, 
                90023, 90024, 90025, 90026, 90027, 90028, 90029, 90031, 90033, 90034, 90035, 90036, 90038, 90039, 
                90041, 90042, 90045, 90046, 90047, 90048, 90049, 90057, 90064, 90065, 90066, 90067, 90068, 90069, 
                90071, 90077, 90089, 90094, 90230, 90501]

# %%
greater_la_zip_codes = [90001, 90004, 90007, 90010, 90012, 90013, 90014, 90015, 90016, 90017, 90018, 90019, 90020, 
                        90021, 90023, 90024, 90025, 90026, 90027, 90028, 90029, 90031, 90033, 90034, 90035, 90036, 
                        90038, 90039, 90041, 90042, 90045, 90046, 90047, 90048, 90049, 90057, 90064, 90065, 90066, 
                        90067, 90068, 90069, 90071, 90077, 90089, 90094, 90230, 90232, 90272, 90291, 90292, 90501, 
                        90710, 90731, 90732, 91040, 91303, 91306, 91307, 91311, 91316, 91324, 91325, 91335, 91342, 
                        91343, 91344, 91345, 91352, 91356, 91364, 91367, 91401, 91402, 91403, 91405, 91406, 91423, 
                        91436, 91601, 91602, 91604, 91605, 91606, 91607, 94608, 94901, 95838]

# %%
california_zip_codes = (sf_zip_codes + greater_la_zip_codes)

# %%
washington_state_zip_codes = seattle_zip_codes

# %%
all_zip_codes = (sf_zip_codes + seattle_zip_codes + greater_la_zip_codes)
all_zip_codes.sort()

# %%
len(all_zip_codes)
# Out:
# 140

# %%
zip_code_df = pd.DataFrame(all_zip_codes, columns=["zipcode"])
zip_code_df.to_csv("data/zipcodes.csv", index=False)

# %% [markdown]
# ## Query and data frame setup

# %%
# Initializing a variable for the total population of the query zip code
total_pop = "B01001_001E"
# Initializing variables to hold the numbers of females aged 24-34, and white females aged 24-34
total_24_29_female = "B01001_035E"
total_30_34_female = "B01001_036E"
total_24_29_female_wht = "B01001A_024E"
total_30_34_female_wht = "B01001A_025E"
# Initializing variables to hold the numbers of males aged 24-34, and white males aged 24-34
total_24_29_male = "B01001_011E"
total_30_34_male = "B01001_012E"
total_24_29_male_wht = "B01001A_009E"
total_30_34_male_wht = "B01001A_010E"
#
total_wht = "B01001A_001E"
# Initializing variables to hold the numbers of college degree-holders living in the query zip code
with_bachelors = "B06009_005E"
with_advanced_deg = "B06009_006E"
# Concatenating all of the above variables into a query string
variables = (total_pop 
             + "," + total_24_29_female 
             + "," + total_30_34_female 
             + "," + total_24_29_male 
             + "," + total_30_34_male 
             + "," + total_24_29_female_wht 
             + "," + total_30_34_female_wht 
             + "," + total_24_29_male_wht 
             + "," + total_30_34_male_wht 
             + "," + total_wht
             + "," + with_bachelors 
             + "," + with_advanced_deg)

# %%
df_columns=[
            "total_pop",
            "total_24_29_female", 
            "total_30_34_female", 
            "total_24_29_male",
            "total_30_34_male",
            "total_24_29_female_wht",
            "total_30_34_female_wht",
            "total_24_29_male_wht",
            "total_30_34_male_wht",
            "total_wht",
            "with_bachelors",
            "with_advanced_deg",
            "zip_code"
           ]

# %% [markdown]
# ## Querying the ACS 5-year API for demographic data for all zip codes for 2009

# %%
o_nine_response = requests.get(f"https://api.census.gov/data/2009/acs5?key={acs_5yr_key}&get=B02001_001E,NAME&for=94706").json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-79-1ec1af9ee6ce> in <module>
# ----> 1 o_nine_response = requests.get(f"https://api.census.gov/data/2009/acs5?key={acs_5yr_key}&get=B02001_001E,NAME&for=94706").json()
#
# /anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
o_nine_response
# Out:
# [['B02001_001E', 'NAME', 'state'],
#  ['36308527', 'California', '06'],
#  ['19423896', 'New York', '36']]

# %%
o_nine_zip_code_response_list = []
for zip_code in all_zip_codes:
    try:
        base_url = f"https://api.census.gov/data/2009/acs5?key={acs_5yr_key}&get="
        query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{zip_code}"
        o_nine_response = requests.get(query_url).json()
        zip_code_df = pd.DataFrame(o_nine_response[1:], columns=df_columns)
        cols = zip_code_df.columns.tolist()
        cols = cols[-2:] + cols[:-2]
        zip_code_df = zip_code_df[cols]
        zip_code_df["year"] = year
        if int(zip_code_df["total_pop"]) > 0:
            zip_code_df["pct_25_34"] = ((int(zip_code_df["total_24_29_female"])
                            + int(zip_code_df["total_30_34_female"]) 
                            + int(zip_code_df["total_24_29_male"])
                            + int(zip_code_df["total_30_34_female"]))
                            / int(zip_code_df["total_pop"])
                           ) * 100
            zip_code_df["pct_college_deg"] = ((int(zip_code_df["with_bachelors"]) 
                                  + int(zip_code_df["with_advanced_deg"]))
                                  / int(zip_code_df["total_pop"])
                                 ) * 100
            zip_code_df["pct_wht"] = (int(zip_code_df["total_wht"]) / int(zip_code_df["total_pop"])) * 100
        else:
            zip_code_df["pct_25_34"] = 0
            zip_code_df["pct_college_deg"] = 0
            zip_code_df["pct_wht"] = 0
        o_nine_zip_code_response_list.append(zip_code_df)
    except json.decoder.JSONDecodeError:
        no_response_list.append(zip_code)
        print(zip_code)
        pass
# Out:
# 90001
# 90004
# 90007
# 90010
# 90012
# 90013
# 90014
# 90015
# 90016
# 90017
# 90018
# 90019
# 90020
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-299d797b3f91> in <module>
#       4         base_url = f"https://api.census.gov/data/2009/acs5?key={acs_5yr_key}&get="
#       5         query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{zip_code}"
# ----> 6         o_nine_response = requests.get(query_url).json()
#       7         zip_code_df = pd.DataFrame(o_nine_response[1:], columns=df_columns)
#       8         cols = zip_code_df.columns.tolist()
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ## Querying the ACS 5-year API for demographic data for all zip codes for 2010

# %%
query_url = f"https://api.census.gov/data/2010/acs/acs5?key={acs_5yr_key}&get=B02001_001E,NAME&for=state:06&in=zip%20code%20tabulation%20area:94706"
query_url = f"https://api.census.gov/data/2010/acs/acs5?key={acs_5yr_key}&get=B02001_001E,NAME&for=place:*&in=state:06"
test_response = requests.get(query_url).json()

# %%
test_response
# Out:
# [['B02001_001E', 'NAME', 'state', 'place'],
#  ['75944', 'Bellflower city, California', '06', '04982'],
#  ['42408', 'Bell Gardens city, California', '06', '04996'],
#  ['25281', 'Belmont city, California', '06', '05108'],
#  ['2116', 'Belvedere city, California', '06', '05164'],
#  ['569', 'Benbow CDP, California', '06', '05262'],
#  ['575', 'Bend CDP, California', '06', '05276'],
#  ['26959', 'Benicia city, California', '06', '05290'],
#  ['6102', 'Ben Lomond CDP, California', '06', '05332'],
#  ['289', 'Benton CDP, California', '06', '05346'],
#  ['109408', 'Berkeley city, California', '06', '06000'],
#  ['6879', 'Bermuda Dunes CDP, California', '06', '06028'],
#  ['1209', 'Berry Creek CDP, California', '06', '06070'],
#  ['2589', 'Bertsch-Oceanview CDP, California', '06', '06150'],
#  ['2191', 'Bethel Island CDP, California', '06', '06210'],
#  ['33980', 'Beverly Hills city, California', '06', '06308'],
#  ['257', 'Bieber CDP, California', '06', '06336'],
#  ['11937', 'Big Bear City CDP, California', '06', '06406'],
#  ['5171', 'Big Bear Lake city, California', '06', '06434'],
#  ['91', 'Big Bend CDP, California', '06', '06475'],
#  ['189', 'Big Creek CDP, California', '06', '06518'],
#  ['2077', 'Biggs city, California', '06', '06560'],
#  ['189', 'Big Lagoon CDP, California', '06', '06567'],
#  ['1682', 'Big Pine CDP, California', '06', '06616'],
#  ['1212', 'Big River CDP, California', '06', '06635'],
#  ['997', 'Biola CDP, California', '06', '06728'],
#  ['3826', 'Bishop city, California', '06', '06798'],
#  ['9607', 'Blackhawk CDP, California', '06', '06928'],
#  ['1195', 'Blacklake CDP, California', '06', '06935'],
#  ['1284', 'Black Point-Green Point CDP, California', '06', '06982'],
#  ['33', 'Blairsden CDP, California', '06', '06994'],
#  ['336', 'Bloomfield CDP, California', '06', '07036'],
#  ['24982', 'Bloomington CDP, California', '06', '07064'],
#  ['1293', 'Blue Lake city, California', '06', '07162'],
#  ['175', 'Bluewater CDP, California', '06', '07172'],
#  ['21164', 'Blythe city, California', '06', '07218'],
#  ['207', 'Bodega CDP, California', '06', '07246'],
#  ['784', 'Bodega Bay CDP, California', '06', '07260'],
#  ['1942', 'Bodfish CDP, California', '06', '07274'],
#  ['1162', 'Bolinas CDP, California', '06', '07316'],
#  ['300', 'Bombay Beach CDP, California', '06', '07372'],
#  ['8940', 'Bonadelle Ranchos-Madera Ranchos CDP, California', '06', '07379'],
#  ['14065', 'Bonita CDP, California', '06', '07414'],
#  ['2410', 'Bonny Doon CDP, California', '06', '07470'],
#  ['4235', 'Bonsall CDP, California', '06', '07498'],
#  ['1048', 'Boonville CDP, California', '06', '07512'],
#  ['918', 'Bootjack CDP, California', '06', '07525'],
#  ['2075', 'Boron CDP, California', '06', '07568'],
#  ['1778', 'Boronda CDP, California', '06', '07578'],
#  ['2412', 'Borrego Springs CDP, California', '06', '07596'],
#  ['14515', 'Bostonia CDP, California', '06', '07624'],
#  ['5386', 'Boulder Creek CDP, California', '06', '07652'],
#  ['31', 'Boulevard CDP, California', '06', '07694'],
#  ['183', 'Bowles CDP, California', '06', '07750'],
#  ['6965', 'Boyes Hot Springs CDP, California', '06', '07848'],
#  ['978', 'Bradbury city, California', '06', '07946'],
#  ['80', 'Bradley CDP, California', '06', '07974'],
#  ['24288', 'Brawley city, California', '06', '08058'],
#  ['38427', 'Brea city, California', '06', '08100'],
#  ['46283', 'Brentwood city, California', '06', '08142'],
#  ['5102', 'Bret Harte CDP, California', '06', '08172'],
#  ['402', 'Bridgeport CDP, California', '06', '08240'],
#  ['4098', 'Brisbane city, California', '06', '08310'],
#  ['3917', 'Broadmoor CDP, California', '06', '08338'],
#  ['1827', 'Brookdale CDP, California', '06', '08478'],
#  ['3495', 'Brooktrails CDP, California', '06', '08530'],
#  ['2712', 'Buckhorn CDP, California', '06', '08680'],
#  ['0', 'Buck Meadows CDP, California', '06', '08716'],
#  ['23', 'Bucks Lake CDP, California', '06', '08744'],
#  ['4609', 'Buellton city, California', '06', '08758'],
#  ['79744', 'Buena Park city, California', '06', '08786'],
#  ['518', 'Buena Vista CDP, California', '06', '08828'],
#  ['102723', 'Burbank city, California', '06', '08954'],
#  ['4927', 'Burbank CDP, California', '06', '08968'],
#  ['28204', 'Burlingame city, California', '06', '09066'],
#  ['3091', 'Burney CDP, California', '06', '09122'],
#  ['232', 'Burnt Ranch CDP, California', '06', '09150'],
#  ['1016', 'Butte Creek Canyon CDP, California', '06', '09310'],
#  ['30', 'Butte Meadows CDP, California', '06', '09318'],
#  ['948', 'Butte Valley CDP, California', '06', '09324'],
#  ['1675', 'Buttonwillow CDP, California', '06', '09332'],
#  ['1200', 'Byron CDP, California', '06', '09346'],
#  ['4010', 'Bystrom CDP, California', '06', '09353'],
#  ['1931', 'Cabazon CDP, California', '06', '09360'],
#  ['22686', 'Calabasas city, California', '06', '09598'],
#  ['36304', 'Calexico city, California', '06', '09710'],
#  ['13264', 'California City city, California', '06', '09780'],
#  ['65', 'California Hot Springs CDP, California', '06', '09822'],
#  ['126', 'California Pines CDP, California', '06', '09834'],
#  ['7869', 'Calimesa city, California', '06', '09864'],
#  ['6953', 'Calipatria city, California', '06', '09878'],
#  ['5147', 'Calistoga city, California', '06', '09892'],
#  ['1436', 'Callender CDP, California', '06', '09948'],
#  ['791', 'Calpella CDP, California', '06', '09990'],
#  ['122', 'Calpine CDP, California', '06', '10004'],
#  ['1627', 'Calwa CDP, California', '06', '10031'],
#  ['777', 'Camanche North Shore CDP, California', '06', '10042'],
#  ['589', 'Camanche Village CDP, California', '06', '10044'],
#  ['63599', 'Camarillo city, California', '06', '10046'],
#  ['6371', 'Cambria CDP, California', '06', '10074'],
#  ['3245', 'Cambrian Park CDP, California', '06', '10088'],
#  ['17211', 'Cameron Park CDP, California', '06', '10256'],
#  ['1732', 'Camino CDP, California', '06', '10270'],
#  ['1725', 'Camino Tassajara CDP, California', '06', '10301'],
#  ['38692', 'Campbell city, California', '06', '10345'],
#  ['66', 'Camp Nelson CDP, California', '06', '10494'],
#  ['2960', 'Campo CDP, California', '06', '10508'],
#  ['10104', 'Camp Pendleton North CDP, California', '06', '10559'],
#  ['13402', 'Camp Pendleton South CDP, California', '06', '10561'],
#  ['188', 'Camptonville CDP, California', '06', '10676'],
#  ['199', 'Canby CDP, California', '06', '10732'],
#  ['190', 'Cantua Creek CDP, California', '06', '10816'],
#  ['0', 'Canyondam CDP, California', '06', '10914'],
#  ['10618', 'Canyon Lake city, California', '06', '10928'],
#  ['9801', 'Capitola city, California', '06', '11040'],
#  ['0', 'Caribou CDP, California', '06', '11166'],
#  ['99753', 'Carlsbad city, California', '06', '11194'],
#  ['3725', 'Carmel-by-the-Sea city, California', '06', '11250'],
#  ['4671', 'Carmel Valley Village CDP, California', '06', '11324'],
#  ['31', 'Carmet CDP, California', '06', '11376'],
#  ['61806', 'Carmichael CDP, California', '06', '11390'],
#  ['291', 'Carnelian Bay CDP, California', '06', '11418'],
#  ['13122', 'Carpinteria city, California', '06', '11446'],
#  ['170', 'Carrick CDP, California', '06', '11481'],
#  ['91299', 'Carson city, California', '06', '11530'],
#  ['54', 'Cartago CDP, California', '06', '11600'],
#  ['2883', 'Caruthers CDP, California', '06', '11614'],
#  ['3123', 'Casa Conejo CDP, California', '06', '11656'],
#  ['19118', 'Casa de Oro-Mount Helix CDP, California', '06', '11691'],
#  ['400', 'Casmalia CDP, California', '06', '11754'],
#  ['828', 'Caspar CDP, California', '06', '11768'],
#  ['458', 'Cassel CDP, California', '06', '11782'],
#  ['18134', 'Castaic CDP, California', '06', '11796'],
#  ['1328', 'Castle Hill CDP, California', '06', '11915'],
#  ['60625', 'Castro Valley CDP, California', '06', '11964'],
#  ['5490', 'Castroville CDP, California', '06', '11978'],
#  ['50597', 'Cathedral City city, California', '06', '12048'],
#  ['993', 'Catheys Valley CDP, California', '06', '12062'],
#  ['2859', 'Cayucos CDP, California', '06', '12132'],
#  ['362', 'Cazadero CDP, California', '06', '12146'],
#  ['1087', 'Cedar Ridge CDP, California', '06', '12300'],
#  ['0', 'Cedar Slope CDP, California', '06', '12314'],
#  ['502', 'Cedarville CDP, California', '06', '12328'],
#  ['307', 'Centerville CDP, California', '06', '12412'],
#  ['44153', 'Ceres city, California', '06', '12524'],
#  ['49432', 'Cerritos city, California', '06', '12552'],
#  ['780', 'Chalfant CDP, California', '06', '12594'],
#  ['1321', 'Challenge-Brownsville CDP, California', '06', '12612'],
#  ['3235', 'Channel Islands Beach CDP, California', '06', '12669'],
#  ['9298', 'Charter Oak CDP, California', '06', '12734'],
#  ['56', 'Cherokee CDP, California', '06', '12818'],
#  ['222', 'Cherokee Strip CDP, California', '06', '12860'],
#  ['13326', 'Cherryland CDP, California', '06', '12902'],
#  ['6115', 'Cherry Valley CDP, California', '06', '12916'],
#  ['1841', 'Chester CDP, California', '06', '12930'],
#  ['85130', 'Chico city, California', '06', '13014'],
#  ['607', 'Chilcoot-Vinton CDP, California', '06', '13077'],
#  ['1553', 'China Lake Acres CDP, California', '06', '13157'],
#  ['128', 'Chinese Camp CDP, California', '06', '13182'],
#  ['77729', 'Chino city, California', '06', '13210'],
#  ['74410', 'Chino Hills city, California', '06', '13214'],
#  ['18090', 'Chowchilla city, California', '06', '13294'],
#  ['1337', 'Chualar CDP, California', '06', '13364'],
#  ['229614', 'Chula Vista city, California', '06', '13392'],
#  ['10108', 'Citrus CDP, California', '06', '13560'],
#  ['84351', 'Citrus Heights city, California', '06', '13588'],
#  ['34713', 'Claremont city, California', '06', '13756'],
#  ['226', 'Clarksburg CDP, California', '06', '13784'],
#  ['1214', 'Clay CDP, California', '06', '13854'],
#  ['10819', 'Clayton city, California', '06', '13882'],
#  ['168', 'Clear Creek CDP, California', '06', '13910'],
#  ['15074', 'Clearlake city, California', '06', '13945'],
#  ['1498', 'Clearlake Oaks CDP, California', '06', '13966'],
#  ['3193', 'Clearlake Riviera CDP, California', '06', '13985'],
#  ['701', 'Cleone CDP, California', '06', '14008'],
#  ['17', 'Clio CDP, California', '06', '14106'],
#  ['98', 'Clipper Mills CDP, California', '06', '14148'],
#  ['8212', 'Cloverdale city, California', '06', '14190'],
#  ['91166', 'Clovis city, California', '06', '14218'],
#  ['604', 'Clyde CDP, California', '06', '14232'],
#  ['38144', 'Coachella city, California', '06', '14260'],
#  ['13086', 'Coalinga city, California', '06', '14274'],
#  ['1606', 'Coarsegold CDP, California', '06', '14288'],
#  ['1938', 'Cobb CDP, California', '06', '14302'],
#  ['177', 'Coffee Creek CDP, California', '06', '14406'],
#  ['783', 'Cohasset CDP, California', '06', '14442'],
#  ['562', 'Cold Springs CDP (El Dorado County), California', '06', '14450'],
#  ['306', 'Cold Springs CDP (Tuolumne County), California', '06', '14454'],
#  ['605', 'Coleville CDP, California', '06', '14484'],
#  ['1766', 'Colfax city, California', '06', '14498'],
#  ['92', 'College City CDP, California', '06', '14554'],
#  ['2131', 'Collierville CDP, California', '06', '14708'],
#  ['1527', 'Colma town, California', '06', '14736'],
#  ['481', 'Coloma CDP, California', '06', '14764'],
#  ['52187', 'Colton city, California', '06', '14890'],
#  ['2504', 'Columbia CDP, California', '06', '14904'],
#  ['5942', 'Colusa city, California', '06', '14946'],
#  ['12758', 'Commerce city, California', '06', '14974'],
#  ['96', 'Comptche CDP, California', '06', '15030'],
#  ['95761', 'Compton city, California', '06', '15044'],
#  ['121326', 'Concord city, California', '06', '16000'],
#  ['793', 'Concow CDP, California', '06', '16035'],
#  ['4021', 'Copperopolis CDP, California', '06', '16210'],
#  ['25136', 'Corcoran city, California', '06', '16224'],
#  ['7546', 'Corning city, California', '06', '16322'],
#  ['150497', 'Corona city, California', '06', '16350'],
#  ['19721', 'Coronado city, California', '06', '16378'],
#  ['2611', 'Coronita CDP, California', '06', '16420'],
#  ['2692', 'Corralitos CDP, California', '06', '16434'],
#  ['9110', 'Corte Madera town, California', '06', '16462'],
#  ['109316', 'Costa Mesa city, California', '06', '16532'],
#  ['7073', 'Cotati city, California', '06', '16560'],
#  ['15453', 'Coto de Caza CDP, California', '06', '16580'],
#  ['3072', 'Cottonwood CDP, California', '06', '16630'],
#  ['162', 'Coultervillle CDP, California', '06', '16644'],
#  ['8819', 'Country Club CDP, California', '06', '16651'],
#  ['371', 'Courtland CDP, California', '06', '16714'],
#  ['1347', 'Covelo CDP, California', '06', '16728'],
#  ['47533', 'Covina city, California', '06', '16742'],
#  ['350', 'Cowan CDP, California', '06', '16762'],
#  ['7676', 'Crescent City city, California', '06', '17022'],
#  ['118', 'Crescent Mills CDP, California', '06', '17050'],
#  ['692', 'Cressey CDP, California', '06', '17078'],
#  ['2144', 'Crest CDP, California', '06', '17106'],
#  ['8936', 'Crestline CDP, California', '06', '17162'],
#  ['290', 'Crestmore Heights CDP, California', '06', '17204'],
#  ['67', 'Creston CDP, California', '06', '17232'],
#  ['268', 'C-Road CDP, California', '06', '17267'],
#  ['3298', 'Crockett CDP, California', '06', '17274'],
#  ['119', 'Cromberg CDP, California', '06', '17288'],
#  ['554', 'Crowley Lake CDP, California', '06', '17372'],
#  ['529', 'Crows Landing CDP, California', '06', '17428'],
#  ['23854', 'Cudahy city, California', '06', '17498'],
#  ['38827', 'Culver City city, California', '06', '17568'],
#  ['56498', 'Cupertino city, California', '06', '17610'],
#  ['5058', 'Cutler CDP, California', '06', '17708'],
#  ['3041', 'Cutten CDP, California', '06', '17722'],
#  ['51', 'Cuyama CDP, California', '06', '17727'],
#  ['47314', 'Cypress city, California', '06', '17750'],
#  ['99829', 'Daly City city, California', '06', '17918'],
#  ['33484', 'Dana Point city, California', '06', '17946'],
#  ['41738', 'Danville town, California', '06', '17988'],
#  ['49', 'Daphnedale Park CDP, California', '06', '17995'],
#  ['30', 'Darwin CDP, California', '06', '18030'],
#  ['309', 'Davenport CDP, California', '06', '18086'],
#  ['64842', 'Davis city, California', '06', '18100'],
#  ['3256', 'Day Valley CDP, California', '06', '18153'],
#  ['1048', 'Deer Park CDP, California', '06', '18324'],
#  ['9582', 'Del Aire CDP, California', '06', '18352'],
#  ['51310', 'Delano city, California', '06', '18394'],
#  ['555', 'Delft Colony CDP, California', '06', '18450'],
#  ['10481', 'Delhi CDP, California', '06', '18464'],
#  ['560', 'Delleker CDP, California', '06', '18485'],
#  ['4178', 'Del Mar city, California', '06', '18506'],
#  ['4254', 'Del Monte Forest CDP, California', '06', '18590'],
#  ['1767', 'Del Rey CDP, California', '06', '18674'],
#  ['1774', 'Del Rey Oaks city, California', '06', '18688'],
#  ['1186', 'Del Rio CDP, California', '06', '18695'],
#  ['4329', 'Denair CDP, California', '06', '18856'],
#  ['401', 'Derby Acres CDP, California', '06', '18926'],
#  ['1350', 'Descanso CDP, California', '06', '18940'],
#  ['188', 'Desert Center CDP, California', '06', '18982'],
#  ['4668', 'Desert Edge CDP, California', '06', '18986'],
#  ['24675', 'Desert Hot Springs city, California', '06', '18996'],
#  ['6745', 'Desert Palms CDP, California', '06', '19022'],
#  ['470', 'Desert Shores CDP, California', '06', '19024'],
#  ['2450', 'Desert View Highlands CDP, California', '06', '19052'],
#  ['1071', 'Diablo CDP, California', '06', '19150'],
#  ['285', 'Diablo Grande CDP, California', '06', '19155'],
#  ['55701', 'Diamond Bar city, California', '06', '19192'],
#  ['11327', 'Diamond Springs CDP, California', '06', '19220'],
#  ['163', 'Dillon Beach CDP, California', '06', '19262'],
#  ['20823', 'Dinuba city, California', '06', '19318'],
#  ['11438', 'Discovery Bay CDP, California', '06', '19339'],
#  ['17924', 'Dixon city, California', '06', '19402'],
#  ['2660', 'Dixon Lane-Meadow Creek CDP, California', '06', '19406'],
#  ['354', 'Dobbins CDP, California', '06', '19416'],
#  ['2299', 'Dogtown CDP, California', '06', '19440'],
#  ['1090', 'Dollar Point CDP, California', '06', '19455'],
#  ['574', 'Dorrington CDP, California', '06', '19570'],
#  ['797', 'Dorris city, California', '06', '19584'],
#  ['4904', 'Dos Palos city, California', '06', '19612'],
#  ['372', 'Dos Palos Y CDP, California', '06', '19654'],
#  ['830', 'Douglas City CDP, California', '06', '19724'],
#  ['110921', 'Downey city, California', '06', '19766'],
#  ['213', 'Downieville CDP, California', '06', '19794'],
#  ['372', 'Doyle CDP, California', '06', '19878'],
#  ['210', 'Drytown CDP, California', '06', '19976'],
#  ['21380', 'Duarte city, California', '06', '19990'],
#  ['42657', 'Dublin city, California', '06', '20018'],
#  ['444', 'Ducor CDP, California', '06', '20032'],
#  ['948', 'Dunnigan CDP, California', '06', '20228'],
#  ['1782', 'Dunsmuir city, California', '06', '20242'],
#  ['5632', 'Durham CDP, California', '06', '20270'],
#  ['606', 'Dustin Acres CDP, California', '06', '20284'],
#  ['154', 'Dutch Flat CDP, California', '06', '20298'],
#  ['70', 'Eagleville CDP, California', '06', '20424'],
#  ['6596', 'Earlimart CDP, California', '06', '20438'],
#  ['7675', 'East Foothills CDP, California', '06', '20598'],
#  ['19962', 'East Hemet CDP, California', '06', '20697'],
#  ['10177', 'East La Mirada CDP, California', '06', '20746'],
#  ['123136', 'East Los Angeles CDP, California', '06', '20802'],
#  ['349', 'East Nicolaus CDP, California', '06', '20900'],
#  ['2972', 'East Oakdale CDP, California', '06', '20907'],
#  ['2017', 'Easton CDP, California', '06', '20928'],
#  ['263', 'East Orosi CDP, California', '06', '20942'],
#  ['27894', 'East Palo Alto city, California', '06', '20956'],
#  ['5752', 'East Pasadena CDP, California', '06', '20984'],
#  ['6498', 'East Porterville CDP, California', '06', '21012'],
#  ['2706', 'East Quincy CDP, California', '06', '21026'],
#  ['13599', 'East Rancho Dominguez CDP, California', '06', '21034'],
#  ['3210', 'East Richmond Heights CDP, California', '06', '21061'],
#  ['15131', 'East San Gabriel CDP, California', '06', '21096'],
#  ['298', 'East Shore CDP, California', '06', '21138'],
#  ['2248', 'East Sonora CDP, California', '06', '21188'],
#  ['1249', 'East Tulare Villa CDP, California', '06', '21210'],
#  ['49131', 'Eastvale CDP, California', '06', '21230'],
#  ['49', 'Edgewood CDP, California', '06', '21530'],
#  ['229', 'Edmundson Acres CDP, California', '06', '21558'],
#  ['30', 'Edna CDP, California', '06', '21565'],
#  ['3565', 'Edwards AFB CDP, California', '06', '21600'],
#  ['97932', 'El Cajon city, California', '06', '21712'],
#  ['41581', 'El Centro city, California', '06', '21782'],
#  ['23320', 'El Cerrito city, California', '06', '21796'],
#  ['5157', 'El Cerrito CDP, California', '06', '21810'],
#  ['43179', 'El Dorado Hills CDP, California', '06', '21880'],
#  ['1757', 'Eldridge CDP, California', '06', '21894'],
#  ['4669', 'El Granada CDP, California', '06', '21936'],
#  ['1609', 'Elizabeth Lake CDP, California', '06', '21964'],
#  ['118', 'Elk Creek CDP, California', '06', '22006'],
#  ['141200', 'Elk Grove city, California', '06', '22020'],
#  ['1720', 'Elkhorn CDP, California', '06', '22034'],
#  ['153', 'Elmira CDP, California', '06', '22146'],
#  ['113888', 'El Monte city, California', '06', '22230'],
#  ['250', 'El Nido CDP, California', '06', '22286'],
#  ['28794', 'El Paso de Robles (Paso Robles) city, California', '06', '22300'],
#  ['378', 'El Portal CDP, California', '06', '22328'],
#  ['47', 'El Rancho CDP, California', '06', '22360'],
#  ['6159', 'El Rio CDP, California', '06', '22370'],
#  ['16534', 'El Segundo city, California', '06', '22412'],
#  ['13489', 'El Sobrante CDP (Contra Costa County), California', '06', '22454'],
#  ['11122', 'El Sobrante CDP (Riverside County), California', '06', '22457'],
#  ['3746', 'El Verano CDP, California', '06', '22510'],
#  ['5044', 'Elverta CDP, California', '06', '22524'],
#  ['4445', 'Emerald Lake Hills CDP, California', '06', '22587'],
#  ['9393', 'Emeryville city, California', '06', '22594'],
#  ['3763', 'Empire CDP, California', '06', '22622'],
#  ['58761', 'Encinitas city, California', '06', '22678'],
#  ['7054', 'Escalon city, California', '06', '22790'],
#  ['140998', 'Escondido city, California', '06', '22804'],
#  ['2720', 'Esparto CDP, California', '06', '22846'],
#  ['650', 'Etna city, California', '06', '22972'],
#  ['5867', 'Eucalyptus Hills CDP, California', '06', '23000'],
#  ['26954', 'Eureka city, California', '06', '23042'],
#  ['10139', 'Exeter city, California', '06', '23126'],
#  ['1976', 'Fairbanks Ranch CDP, California', '06', '23150'],
#  ['7346', 'Fairfax town, California', '06', '23168'],
#  ['103698', 'Fairfield city, California', '06', '23182'],
#  ['935', 'Fairmead CDP, California', '06', '23210'],
#  ['30715', 'Fair Oaks CDP, California', '06', '23294'],
#  ['9812', 'Fairview CDP, California', '06', '23350'],
#  ['29892', 'Fallbrook CDP, California', '06', '23462'],
#  ['545', 'Fall River Mills CDP, California', '06', '23532'],
#  ['10283', 'Farmersville city, California', '06', '23616'],
#  ['300', 'Farmington CDP, California', '06', '23630'],
#  ['162', 'Fellows CDP, California', '06', '23812'],
#  ['4528', 'Felton CDP, California', '06', '23826'],
#  ['1693', 'Ferndale city, California', '06', '23910'],
#  ['3504', 'Fetters Hot Springs-Agua Caliente CDP, California', '06', '23973'],
#  ['83', 'Fiddletown CDP, California', '06', '23980'],
#  ['927', 'Fieldbrook CDP, California', '06', '24008'],
#  ['259', 'Fields Landing CDP, California', '06', '24022'],
#  ['14721', 'Fillmore city, California', '06', '24092'],
#  ['7373', 'Firebaugh city, California', '06', '24134'],
#  ['0', 'Fish Camp CDP, California', '06', '24218'],
#  ['60834', 'Florence-Graham CDP, California', '06', '24477'],
#  ['47869', 'Florin CDP, California', '06', '24498'],
#  ['27', 'Floriston CDP, California', '06', '24526'],
#  ['110', 'Flournoy CDP, California', '06', '24568'],
#  ['69068', 'Folsom city, California', '06', '24638'],
#  ['189466', 'Fontana city, California', '06', '24680'],
#  ['32800', 'Foothill Farms CDP, California', '06', '24722'],
#  ['355', 'Forbestown CDP, California', '06', '24750'],
#  ['3684', 'Ford City CDP, California', '06', '24764'],
#  ['1895', 'Foresthill CDP, California', '06', '24834'],
#  ['1551', 'Forest Meadows CDP, California', '06', '24897'],
#  ['1335', 'Forest Ranch CDP, California', '06', '24918'],
#  ['3380', 'Forestville CDP, California', '06', '24960'],
#  ['140', 'Fort Bidwell CDP, California', '06', '25030'],
#  ['7196', 'Fort Bragg city, California', '06', '25058'],
#  ['9107', 'Fort Irwin CDP, California', '06', '25114'],
#  ['520', 'Fort Jones city, California', '06', '25128'],
#  ['11646', 'Fortuna city, California', '06', '25296'],
#  ['432', 'Fort Washington CDP, California', '06', '25300'],
#  ['29746', 'Foster City city, California', '06', '25338'],
#  ['54961', 'Fountain Valley city, California', '06', '25380'],
#  ['5305', 'Fowler city, California', '06', '25436'],
#  ['5177', 'Franklin CDP (Merced County), California', '06', '25488'],
#  ['0', 'Franklin CDP (Sacramento County), California', '06', '25506'],
#  ['2393', 'Frazier Park CDP, California', '06', '25534'],
#  ['2816', 'Freedom CDP, California', '06', '25576'],
#  ['20', 'Freeport CDP, California', '06', '25590'],
#  ['1612', 'Acalanes Ridge CDP, California', '06', '00135'],
#  ['25', 'Acampo CDP, California', '06', '00156'],
#  ['7150', 'Acton CDP, California', '06', '00212'],
#  ['29764', 'Adelanto city, California', '06', '00296'],
#  ['374', 'Adin CDP, California', '06', '00310'],
#  ['20328', 'Agoura Hills city, California', '06', '00394'],
#  ['2864', 'Agua Dulce CDP, California', '06', '00450'],
#  ['1430', 'Aguanga CDP, California', '06', '00464'],
#  ['2097', 'Ahwahnee CDP, California', '06', '00478'],
#  ['1590', 'Airport CDP, California', '06', '00535'],
#  ['72512', 'Alameda city, California', '06', '00562'],
#  ['15177', 'Alamo CDP, California', '06', '00618'],
#  ['17921', 'Albany city, California', '06', '00674'],
#  ['224', 'Albion CDP, California', '06', '00716'],
#  ['210', 'Alderpoint CDP, California', '06', '00786'],
#  ['83389', 'Alhambra city, California', '06', '00884'],
#  ['825', 'Alhambra Valley CDP, California', '06', '00898'],
#  ['46329', 'Aliso Viejo city, California', '06', '00947'],
#  ['53', 'Alleghany CDP, California', '06', '00982'],
#  ['1726', 'Allendale CDP, California', '06', '00996'],
#  ['228', 'Allensworth CDP, California', '06', '01010'],
#  ['10', 'Almanor CDP, California', '06', '01094'],
#  ['8817', 'Alondra Park CDP, California', '06', '01150'],
#  ['953', 'Alpaugh CDP, California', '06', '01164'],
#  ['13326', 'Alpine CDP, California', '06', '01192'],
#  ['237', 'Alpine Village CDP, California', '06', '01228'],
#  ['513', 'Alta CDP, California', '06', '01276'],
#  ['45446', 'Altadena CDP, California', '06', '01290'],
#  ['7011', 'Alta Sierra CDP, California', '06', '01360'],
#  ['579', 'Alto CDP, California', '06', '01416'],
#  ['2833', 'Alturas city, California', '06', '01444'],
#  ['16049', 'Alum Rock CDP, California', '06', '01458'],
#  ['128', 'Amador City city, California', '06', '01514'],
#  ['17692', 'American Canyon city, California', '06', '01640'],
#  ['3339', 'Amesti CDP, California', '06', '01651'],
#  ['333039', 'Anaheim city, California', '06', '02000'],
#  ['319', 'Anchor Bay CDP, California', '06', '02028'],
#  ['9910', 'Anderson city, California', '06', '02042'],
#  ['3790', 'Angels city, California', '06', '02112'],
#  ['3737', 'Angwin CDP, California', '06', '02168'],
#  ['45691', 'Antelope CDP, California', '06', '02210'],
#  ['99717', 'Antioch city, California', '06', '02252'],
#  ['2789', 'Anza CDP, California', '06', '02294'],
#  ['67396', 'Apple Valley town, California', '06', '02364'],
#  ['6255', 'Aptos CDP, California', '06', '02378'],
#  ['2384', 'Aptos Hills-Larkin Valley CDP, California', '06', '02382'],
#  ['3206', 'Arbuckle CDP, California', '06', '02420'],
#  ['55704', 'Arcadia city, California', '06', '02462'],
#  ['17100', 'Arcata city, California', '06', '02476'],
#  ['90920', 'Arden-Arcade CDP, California', '06', '02553'],
#  ['3046', 'Armona CDP, California', '06', '02700'],
#  ['3439', 'Arnold CDP, California', '06', '02770'],
#  ['2318', 'Aromas CDP, California', '06', '02812'],
#  ['16990', 'Arroyo Grande city, California', '06', '02868'],
#  ['16476', 'Artesia city, California', '06', '02896'],
#  ['142', 'Artois CDP, California', '06', '02910'],
#  ['18329', 'Arvin city, California', '06', '02924'],
#  ['22098', 'Ashland CDP, California', '06', '02980'],
#  ['0', 'Aspen Springs CDP, California', '06', '03026'],
#  ['27981', 'Atascadero city, California', '06', '03064'],
#  ['6837', 'Atherton town, California', '06', '03092'],
#  ['27587', 'Atwater city, California', '06', '03162'],
#  ['2212', 'Auberry CDP, California', '06', '03190'],
#  ['13451', 'Auburn city, California', '06', '03204'],
#  ['3953', 'Auburn Lake Trails CDP, California', '06', '03205'],
#  ['8332', 'August CDP, California', '06', '03209'],
#  ['3661', 'Avalon city, California', '06', '03274'],
#  ['15749', 'Avenal city, California', '06', '03302'],
#  ['381', 'Avery CDP, California', '06', '03316'],
#  ['1021', 'Avilla Beach CDP, California', '06', '03330'],
#  ['15473', 'Avocado Heights CDP, California', '06', '03344'],
#  ['46015', 'Azusa city, California', '06', '03386'],
#  ['676', 'Baker CDP, California', '06', '03512'],
#  ['331868', 'Bakersfield city, California', '06', '03526'],
#  ['75387', 'Baldwin Park city, California', '06', '03666'],
#  ['569', 'Ballard CDP, California', '06', '03694'],
#  ['431', 'Ballico CDP, California', '06', '03708'],
#  ['370', 'Bangor CDP, California', '06', '03792'],
#  ['29030', 'Banning city, California', '06', '03820'],
#  ['22983', 'Barstow city, California', '06', '04030'],
#  ['463', 'Bass Lake CDP, California', '06', '04198'],
#  ['21197', 'Bay Point CDP, California', '06', '04415'],
#  ['2200', 'Bayview CDP (Contra Costa County), California', '06', '04470'],
#  ['2640', 'Bayview CDP (Humboldt County), California', '06', '04478'],
#  ['2127', 'Beale AFB CDP, California', '06', '04576'],
#  ['263', 'Bear Creek CDP, California', '06', '04632'],
#  ['67', 'Bear Valley CDP (Alpine County), California', '06', '04716'],
#  ['272', 'Bear Valley CDP (Mariposa County), California', '06', '04730'],
#  ['6011', 'Bear Valley Springs CDP, California', '06', '04734'],
#  ['32847', 'Beaumont city, California', '06', '04758'],
#  ['415', 'Beckwourth CDP, California', '06', '04772'],
#  ['78', 'Belden CDP, California', '06', '04856'],
#  ['35648', 'Bell city, California', '06', '04870'],
#  ['2303', 'Bella Vista CDP, California', '06', '04926'],
#  ['2457', 'Bell Canyon CDP, California', '06', '04938'],
#  ['191', 'Rutherford CDP, California', '06', '63400'],
#  ['459511', 'Sacramento city, California', '06', '64000'],
#  ['5818', 'St. Helena city, California', '06', '64140'],
#  ['14625', 'Salida CDP, California', '06', '64210'],
#  ['147074', 'Salinas city, California', '06', '64224'],
#  ['83', 'Salmon Creek CDP, California', '06', '64252'],
#  ['1400', 'Salton City CDP, California', '06', '64294'],
#  ['464', 'Salton Sea Beach CDP, California', '06', '64308'],
#  ['273', 'Samoa CDP, California', '06', '64392'],
#  ['2708', 'San Andreas CDP, California', '06', '64420'],
#  ['12203', 'San Anselmo town, California', '06', '64434'],
#  ['3979', 'San Antonio Heights CDP, California', '06', '64462'],
#  ['665', 'San Ardo CDP, California', '06', '64476'],
#  ['209174', 'San Bernardino city, California', '06', '65000'],
#  ['40231', 'San Bruno city, California', '06', '65028'],
#  ['105211', 'San Buenaventura (Ventura) city, California', '06', '65042'],
#  ['27830', 'San Carlos city, California', '06', '65070'],
#  ['60774', 'San Clemente city, California', '06', '65084'],
#  ['234', 'Sand City city, California', '06', '65112'],
#  ['1282800', 'San Diego city, California', '06', '66000'],
#  ['10657', 'San Diego Country Estates CDP, California', '06', '66004'],
#  ['33635', 'San Dimas city, California', '06', '66070'],
#  ['23623', 'San Fernando city, California', '06', '66140'],
#  ['789172', 'San Francisco city, California', '06', '67000'],
#  ['39670', 'San Gabriel city, California', '06', '67042'],
#  ['23370', 'Sanger city, California', '06', '67056'],
#  ['562', 'San Geronimo CDP, California', '06', '67070'],
#  ['41203', 'San Jacinto city, California', '06', '67112'],
#  ['3927', 'San Joaquin city, California', '06', '67126'],
#  ['925300', 'San Jose city, California', '06', '68000'],
#  ['1462', 'San Juan Bautista city, California', '06', '68014'],
#  ['34263', 'San Juan Capistrano city, California', '06', '68028'],
#  ['82830', 'San Leandro city, California', '06', '68084'],
#  ['23562', 'San Lorenzo CDP, California', '06', '68112'],
#  ['191', 'San Lucas CDP, California', '06', '68140'],
#  ['44959', 'San Luis Obispo city, California', '06', '68154'],
#  ['78127', 'San Marcos city, California', '06', '68196'],
#  ['13114', 'San Marino city, California', '06', '68224'],
#  ['7250', 'San Martin CDP, California', '06', '68238'],
#  ['94751', 'San Mateo city, California', '06', '68252'],
#  ['3381', 'San Miguel CDP (Contra Costa County), California', '06', '68263'],
#  ['2695',
#   'San Miguel CDP (San Luis Obispo County), California',
#   '06',
#   '68266'],
#  ['29136', 'San Pablo city, California', '06', '68294'],
#  ['2052', 'San Pasqual CDP, California', '06', '68308'],
#  ['56930', 'San Rafael city, California', '06', '68364'],
#  ['66822', 'San Ramon city, California', '06', '68378'],
#  ['547', 'San Simeon CDP, California', '06', '68434'],
#  ['325216', 'Santa Ana city, California', '06', '69000'],
#  ['87859', 'Santa Barbara city, California', '06', '69070'],
#  ['112466', 'Santa Clara city, California', '06', '69084'],
#  ['172253', 'Santa Clarita city, California', '06', '69088'],
#  ['58269', 'Santa Cruz city, California', '06', '69112'],
#  ['16376', 'Santa Fe Springs city, California', '06', '69154'],
#  ['1431', 'Santa Margarita CDP, California', '06', '69182'],
#  ['94645', 'Santa Maria city, California', '06', '69196'],
#  ['88679', 'Santa Monica city, California', '06', '70000'],
#  ['1262', 'Santa Nella CDP, California', '06', '70028'],
#  ['29145', 'Santa Paula city, California', '06', '70042'],
#  ['162647', 'Santa Rosa city, California', '06', '70098'],
#  ['3223', 'Santa Rosa Valley CDP, California', '06', '70130'],
#  ['1301', 'Santa Susana CDP, California', '06', '70140'],
#  ['5102', 'Santa Venetia CDP, California', '06', '70154'],
#  ['4862', 'Santa Ynez CDP, California', '06', '70182'],
#  ['52966', 'Santee city, California', '06', '70224'],
#  ['4920', 'Saranap CDP, California', '06', '70266'],
#  ['29523', 'Saratoga city, California', '06', '70280'],
#  ['905', 'Saticoy CDP, California', '06', '70322'],
#  ['22', 'Sattley CDP, California', '06', '70336'],
#  ['7009', 'Sausalito city, California', '06', '70364'],
#  ['652', 'Scotia CDP, California', '06', '70518'],
#  ['11351', 'Scotts Valley city, California', '06', '70588'],
#  ['2990', 'Seacliff CDP, California', '06', '70644'],
#  ['24081', 'Seal Beach city, California', '06', '70686'],
#  ['801', 'Sea Ranch CDP, California', '06', '70712'],
#  ['2088', 'Searles Valley CDP, California', '06', '70728'],
#  ['32431', 'Seaside city, California', '06', '70742'],
#  ['7335', 'Sebastopol city, California', '06', '70770'],
#  ['1861', 'Seeley CDP, California', '06', '70798'],
#  ['22617', 'Selma city, California', '06', '70882'],
#  ['0', 'Sequoia Crest CDP, California', '06', '70966'],
#  ['123', 'Sereno del Mar CDP, California', '06', '71000'],
#  ['646', 'Seville CDP, California', '06', '71078'],
#  ['3748', 'Shackelford CDP, California', '06', '71084'],
#  ['16378', 'Shafter city, California', '06', '71106'],
#  ['939', 'Shandon CDP, California', '06', '71134'],
#  ['1572', 'Shasta CDP, California', '06', '71218'],
#  ['10081', 'Shasta Lake city, California', '06', '71225'],
#  ['708', 'Shaver Lake CDP, California', '06', '71246'],
#  ['1381', 'Shell Ridge CDP, California', '06', '71362'],
#  ['524', 'Shelter Cove CDP, California', '06', '71372'],
#  ['1615', 'Sheridan CDP, California', '06', '71414'],
#  ['3926', 'Shingle Springs CDP, California', '06', '71554'],
#  ['2084', 'Shingletown CDP, California', '06', '71568'],
#  ['33', 'Shoshone CDP, California', '06', '71680'],
#  ['210', 'Sierra Brooks CDP, California', '06', '71774'],
#  ['601', 'Sierra City CDP, California', '06', '71778'],
#  ['10854', 'Sierra Madre city, California', '06', '71806'],
#  ['152', 'Sierra Village CDP, California', '06', '71834'],
#  ['250', 'Sierraville CDP, California', '06', '71848'],
#  ['10700', 'Signal Hill city, California', '06', '71876'],
#  ['1244', 'Silverado Resort CDP, California', '06', '71927'],
#  ['0', 'Silver City CDP, California', '06', '71932'],
#  ['3860', 'Silver Lakes CDP, California', '06', '71964'],
#  ['121662', 'Simi Valley city, California', '06', '72016'],
#  ['165', 'Sisquoc CDP, California', '06', '72086'],
#  ['1838', 'Sky Valley CDP, California', '06', '72156'],
#  ['2443', 'Sleepy Hollow CDP, California', '06', '72184'],
#  ['221', 'Smartsville CDP, California', '06', '72282'],
#  ['287', 'Smith Corner CDP, California', '06', '72338'],
#  ['1050', 'Smith River CDP, California', '06', '72380'],
#  ['141', 'Snelling CDP, California', '06', '72408'],
#  ['945', 'Soda Bay CDP, California', '06', '72478'],
#  ['128', 'Soda Springs CDP, California', '06', '72492'],
#  ['12790', 'Solana Beach city, California', '06', '72506'],
#  ['25350', 'Soledad city, California', '06', '72520'],
#  ['5218', 'Solvang city, California', '06', '72576'],
#  ['10292', 'Sonoma city, California', '06', '72646'],
#  ['4914', 'Sonora city, California', '06', '72674'],
#  ['9392', 'Soquel CDP, California', '06', '72688'],
#  ['2031', 'Soulsbyville CDP, California', '06', '72772'],
#  ['2271', 'South Dos Palos CDP, California', '06', '72954'],
#  ['20240', 'South El Monte city, California', '06', '72996'],
#  ['94683', 'South Gate city, California', '06', '73080'],
#  ['22114', 'South Lake Tahoe city, California', '06', '73108'],
#  ['6443', 'South Monrovia Island CDP, California', '06', '73167'],
#  ['6688', 'South Oroville CDP, California', '06', '73178'],
#  ['25376', 'South Pasadena city, California', '06', '73220'],
#  ['62016', 'South San Francisco city, California', '06', '73262'],
#  ['8136', 'South San Gabriel CDP, California', '06', '73276'],
#  ['21379', 'South San Jose Hills CDP, California', '06', '73290'],
#  ['2177', 'South Taft CDP, California', '06', '73388'],
#  ['56882', 'South Whittier CDP, California', '06', '73430'],
#  ['172', 'Spaulding CDP, California', '06', '73554'],
#  ['621', 'Spreckels CDP, California', '06', '73612'],
#  ['0', 'Spring Garden CDP, California', '06', '73654'],
#  ['822', 'Spring Valley CDP (Lake County), California', '06', '73690'],
#  ['27300', 'Spring Valley CDP (San Diego County), California', '06', '73696'],
#  ['7640', 'Spring Valley Lake CDP, California', '06', '73700'],
#  ['1269', 'Springville CDP, California', '06', '73710'],
#  ['2435', 'Squaw Valley CDP, California', '06', '73794'],
#  ['662', 'Squirrel Mountain Valley CDP, California', '06', '73815'],
#  ['2454', 'Stallion Springs CDP, California', '06', '73868'],
#  ['14256', 'Stanford CDP, California', '06', '73906'],
#  ['37990', 'Stanton city, California', '06', '73962'],
#  ['16934', 'Stevenson Ranch CDP, California', '06', '74130'],
#  ['239', 'Stevinson CDP, California', '06', '74144'],
#  ['446', 'Stinson Beach CDP, California', '06', '74172'],
#  ['277', 'Stirling City CDP, California', '06', '74186'],
#  ['287377', 'Stockton city, California', '06', '75000'],
#  ['119', 'Stonyford CDP, California', '06', '75154'],
#  ['0', 'Storrie CDP, California', '06', '75168'],
#  ['1301', 'Stratford CDP, California', '06', '75252'],
#  ['3298', 'Strathmore CDP, California', '06', '75280'],
#  ['5138', 'Strawberry CDP (Marin County), California', '06', '75315'],
#  ['64', 'Strawberry CDP (Tuolumne County), California', '06', '75322'],
#  ['0', 'Sugarloaf Mountain Park CDP, California', '06', '75588'],
#  ['0', 'Sugarloaf Saw Mill CDP, California', '06', '75592'],
#  ['17', 'Sugarloaf Village CDP, California', '06', '75596'],
#  ['27742', 'Suisun City city, California', '06', '75630'],
#  ['442', 'Sultana CDP, California', '06', '75672'],
#  ['1083', 'Summerland CDP, California', '06', '75714'],
#  ['4558', 'Sunnyside CDP, California', '06', '75994'],
#  ['1552', 'Sunnyside-Tahoe City CDP, California', '06', '76015'],
#  ['4896', 'Sunnyslope CDP, California', '06', '76022'],
#  ['198', 'Sunny Slopes CDP, California', '06', '76040'],
#  ['136480', 'Sunnyvale city, California', '06', '77000'],
#  ['747', 'Sunol CDP, California', '06', '77042'],
#  ['1253', 'Sunset Beach CDP, California', '06', '77126'],
#  ['10692', 'Sun Village CDP, California', '06', '77308'],
#  ['17460', 'Susanville city, California', '06', '77364'],
#  ['2924', 'Sutter CDP, California', '06', '77378'],
#  ['2827', 'Sutter Creek city, California', '06', '77392'],
#  ['397', 'Swall Meadows CDP, California', '06', '77430'],
#  ['9370', 'Taft city, California', '06', '77574'],
#  ['1906', 'Taft Heights CDP, California', '06', '77588'],
#  ['1528', 'Taft Mosswood CDP, California', '06', '77595'],
#  ['1539', 'Tahoe Vista CDP, California', '06', '77700'],
#  ['1038', 'Tahoma CDP, California', '06', '77728'],
#  ['1040', 'Talmage CDP, California', '06', '77784'],
#  ['10601', 'Tamalpais-Homestead Valley CDP, California', '06', '77805'],
#  ['4611', 'Tara Hills CDP, California', '06', '77924'],
#  ['3962', 'Tarpey Village CDP, California', '06', '77960'],
#  ['122', 'Taylorsville CDP, California', '06', '78008'],
#  ['101', 'Tecopa CDP, California', '06', '78050'],
#  ['14080', 'Tehachapi city, California', '06', '78092'],
#  ['436', 'Tehama city, California', '06', '78106'],
#  ['95829', 'Temecula city, California', '06', '78120'],
#  ['1453', 'Temelec CDP, California', '06', '78126'],
#  ['22630', 'Temescal Valley CDP, California', '06', '78134'],
#  ['35222', 'Temple City city, California', '06', '78148'],
#  ['8015', 'Templeton CDP, California', '06', '78162'],
#  ['46', 'Tennant CDP, California', '06', '78176'],
#  ['409', 'Terminous CDP, California', '06', '78232'],
#  ['3551', 'Terra Bella CDP, California', '06', '78288'],
#  ['1044', 'Teviston CDP, California', '06', '78336'],
#  ['2490', 'Thermal CDP, California', '06', '78456'],
#  ['6001', 'Thermalito CDP, California', '06', '78470'],
#  ['847', 'Thornton CDP, California', '06', '78568'],
#  ['124671', 'Thousand Oaks city, California', '06', '78582'],
#  ['7185', 'Thousand Palms CDP, California', '06', '78596'],
#  ['1949', 'Three Rivers CDP, California', '06', '78638'],
#  ['168', 'Three Rocks CDP, California', '06', '78652'],
#  ['8831', 'Tiburon town, California', '06', '78666'],
#  ['149', 'Timber Cove CDP, California', '06', '78715'],
#  ['2172', 'Tipton CDP, California', '06', '78750'],
#  ['0', 'Tobin CDP, California', '06', '78792'],
#  ['255', 'Tomales CDP, California', '06', '78890'],
#  ['262', 'Tonyville CDP, California', '06', '78932'],
#  ['200', 'Tooleville CDP, California', '06', '78949'],
#  ['8520', 'Topanga CDP, California', '06', '78960'],
#  ['0', 'Topaz CDP, California', '06', '79030'],
#  ['1344', 'Toro Canyon CDP, California', '06', '79529'],
#  ['143951', 'Torrance city, California', '06', '80000'],
#  ['79416', 'Tracy city, California', '06', '80238'],
#  ['1224', 'Tranquillity CDP, California', '06', '80266'],
#  ['1175', 'Traver CDP, California', '06', '80280'],
#  ['266', 'Tres Pinos CDP, California', '06', '80364'],
#  ['259', 'Trinidad city, California', '06', '80448'],
#  ['209', 'Trinity Center CDP, California', '06', '80476'],
#  ['128', 'Trinity Village CDP, California', '06', '80483'],
#  ['17', 'Trona CDP, California', '06', '80515'],
#  ['151', 'Trowbridge CDP, California', '06', '80560'],
#  ['15864', 'Truckee town, California', '06', '80588'],
#  ['56938', 'Tulare city, California', '06', '80644'],
#  ['895', 'Tulelake city, California', '06', '80686'],
#  ['2039', 'Tuolumne City CDP, California', '06', '80763'],
#  ['119', 'Tupman CDP, California', '06', '80784'],
#  ['67376', 'Turlock city, California', '06', '80812'],
#  ['73731', 'Tustin city, California', '06', '80854'],
#  ['55', 'Tuttle CDP, California', '06', '80882'],
#  ['845', 'Tuttletown CDP, California', '06', '80896'],
#  ['67', 'Twain CDP, California', '06', '80952'],
#  ['2262', 'Twain Harte CDP, California', '06', '80966'],
#  ['26215', 'Twentynine Palms city, California', '06', '80994'],
#  ['5005', 'Twin Lakes CDP, California', '06', '81050'],
#  ['15942', 'Ukiah city, California', '06', '81134'],
#  ['68081', 'Union City city, California', '06', '81204'],
#  ['7710', 'University of California Davis CDP, California', '06', '81302'],
#  ['0', 'University of California Merced CDP, California', '06', '81312'],
#  ['73887', 'Upland city, California', '06', '81344'],
#  ['1213', 'Upper Lake CDP, California', '06', '81358'],
#  ['91928', 'Vacaville city, California', '06', '81554'],
#  ['22157', 'Valinda CDP, California', '06', '81638'],
#  ['538', 'Vallecito CDP, California', '06', '81652'],
#  ['116030', 'Vallejo city, California', '06', '81666'],
#  ['13957', 'Valle Vista CDP, California', '06', '81708'],
#  ['562', 'Valley Acres CDP, California', '06', '81722'],
#  ['9022', 'Valley Center CDP, California', '06', '81736'],
#  ['86', 'Valley Ford CDP, California', '06', '81778'],
#  ['483', 'Valley Home CDP, California', '06', '81792'],
#  ['119', 'Valley Ranch CDP, California', '06', '81869'],
#  ['4031', 'Valley Springs CDP, California', '06', '81890'],
#  ['0', 'Valley Wells CDP, California', '06', '81925'],
#  ['2603', 'Val Verde CDP, California', '06', '81967'],
#  ['3744', 'Vandenberg AFB CDP, California', '06', '82072'],
#  ['6317', 'Vandenberg Village CDP, California', '06', '82086'],
#  ['185', 'Verdi CDP, California', '06', '82334'],
#  ['128', 'Vernon city, California', '06', '82422'],
#  ['274', 'Victor CDP, California', '06', '82562'],
#  ['108088', 'Victorville city, California', '06', '82590'],
#  ['10768', 'View Park-Windsor Hills CDP, California', '06', '82667'],
#  ['5813', 'Villa Park city, California', '06', '82744'],
#  ['72', 'Vina CDP, California', '06', '82786'],
#  ['16204', 'Vincent CDP, California', '06', '82814'],
#  ['3435', 'Vine Hill CDP, California', '06', '82842'],
#  ['25388', 'Vineyard CDP, California', '06', '82852'],
#  ['119312', 'Visalia city, California', '06', '82954'],
#  ['92478', 'Vista city, California', '06', '82996'],
#  ['3155', 'Vista Santa Rosa CDP, California', '06', '83085'],
#  ['177', 'Volcano CDP, California', '06', '83094'],
#  ['116', 'Volta CDP, California', '06', '83108'],
#  ['5596', 'Contra Costa Centre CDP, California', '06', '83215'],
#  ['677', 'Walker CDP, California', '06', '83262'],
#  ['160', 'Wallace CDP, California', '06', '83304'],
#  ['29327', 'Walnut city, California', '06', '83332'],
#  ['63808', 'Walnut Creek city, California', '06', '83346'],
#  ['1409', 'Walnut Grove CDP, California', '06', '83374'],
#  ['16686', 'Walnut Park CDP, California', '06', '83402'],
#  ['2117', 'Warm Springs CDP, California', '06', '83460'],
#  ['0', 'Warner Valley CDP, California', '06', '83494'],
#  ['25143', 'Wasco city, California', '06', '83542'],
#  ['37', 'Washington CDP, California', '06', '83570'],
#  ['8315', 'Waterford city, California', '06', '83612'],
#  ['287', 'Waterloo CDP, California', '06', '83626'],
#  ['49580', 'Watsonville city, California', '06', '83668'],
#  ['154', 'Waukena CDP, California', '06', '83724'],
#  ['311', 'Wawona CDP, California', '06', '83766'],
#  ['3987', 'Weaverville CDP, California', '06', '83794'],
#  ['2950', 'Weed city, California', '06', '83850'],
#  ['2429', 'Weedpatch CDP, California', '06', '83863'],
#  ['2304', 'Weldon CDP, California', '06', '83948'],
#  ['176', 'Weott CDP, California', '06', '84004'],
#  ['8307', 'West Athens CDP, California', '06', '84116'],
#  ['2724', 'West Bishop CDP, California', '06', '84120'],
#  ['20940', 'West Carson CDP, California', '06', '84144'],
#  ['105552', 'West Covina city, California', '06', '84200'],
#  ['359', 'West Goshen CDP, California', '06', '84345'],
#  ['857', 'Westhaven-Moonstone CDP, California', '06', '84385'],
#  ['34657', 'West Hollywood city, California', '06', '84410'],
#  ['8274', 'Westlake Village city, California', '06', '84438'],
#  ['1818', 'Westley CDP, California', '06', '84480'],
#  ['3401', 'West Menlo Park CDP, California', '06', '84536'],
#  ['88921', 'Westminster city, California', '06', '84550'],
#  ['6222', 'West Modesto CDP, California', '06', '84578'],
#  ['31301', 'Westmont CDP, California', '06', '84592'],
#  ['1767', 'Westmorland city, California', '06', '84606'],
#  ['1079', 'West Park CDP, California', '06', '84680'],
#  ['852', 'West Point CDP, California', '06', '84732'],
#  ['22823', 'West Puente Valley CDP, California', '06', '84774'],
#  ['5761', 'West Rancho Dominguez CDP, California', '06', '84780'],
#  ['45961', 'West Sacramento city, California', '06', '84816'],
#  ['25188', 'West Whittier-Los Nietos CDP, California', '06', '84921'],
#  ['1078', 'Westwood CDP, California', '06', '84928'],
#  ['3319', 'Wheatland city, California', '06', '85012'],
#  ['12', 'Whitehawk CDP, California', '06', '85086'],
#  ['661', 'Whitewater CDP, California', '06', '85206'],
#  ['372', 'Whitley Gardens CDP, California', '06', '85222'],
#  ['84997', 'Whittier city, California', '06', '85292'],
#  ['30637', 'Wildomar city, California', '06', '85446'],
#  ['563', 'Wilkerson CDP, California', '06', '85551'],
#  ['4906', 'Williams city, California', '06', '85586'],
#  ['4913', 'Willits city, California', '06', '85600'],
#  ['35174', 'Willowbrook CDP, California', '06', '85614'],
#  ['1276', 'Willow Creek CDP, California', '06', '85642'],
#  ['6205', 'Willows city, California', '06', '85684'],
#  ['0', 'Wilsonia CDP, California', '06', '85866'],
#  ['5008', 'Wilton CDP, California', '06', '85880'],
#  ['2844', 'Winchester CDP, California', '06', '85894'],
#  ['25760', 'Windsor town, California', '06', '85922'],
#  ['20193', 'Winter Gardens CDP, California', '06', '85992'],
#  ['868', 'Winterhaven CDP, California', '06', '86020'],
#  ['6572', 'Winters city, California', '06', '86034'],
#  ['11103', 'Winton CDP, California', '06', '86076'],
#  ['2497', 'Wofford Heights CDP, California', '06', '86174'],
#  ['1249', 'Woodacre CDP, California', '06', '86216'],
#  ['4415', 'Woodbridge CDP, California', '06', '86230'],
#  ['14296', 'Woodcrest CDP, California', '06', '86244'],
#  ['7178', 'Woodlake city, California', '06', '86300'],
#  ['54785', 'Woodland city, California', '06', '86328'],
#  ['372', 'Woodlands CDP, California', '06', '86380'],
#  ['5237', 'Woodside town, California', '06', '86440'],
#  ['1866', 'Woodville CDP, California', '06', '86482'],
#  ['4566', 'Wrightwood CDP, California', '06', '86594'],
#  ['284', 'Yankee Hill CDP, California', '06', '86678'],
#  ['160', 'Yettem CDP, California', '06', '86734'],
#  ['319', 'Yolo CDP, California', '06', '86804'],
#  ['62915', 'Yorba Linda city, California', '06', '86832'],
#  ['4739', 'Yosemite Lakes CDP, California', '06', '86878'],
#  ['361', 'Yosemite Valley CDP, California', '06', '86912'],
#  ['2939', 'Yountville city, California', '06', '86930'],
#  ['7676', 'Yreka city, California', '06', '86944'],
#  ['63435', 'Yuba City city, California', '06', '86972'],
#  ['50227', 'Yucaipa city, California', '06', '87042'],
#  ['20290', 'Yucca Valley town, California', '06', '87056'],
#  ['810', 'Zayante CDP, California', '06', '87090'],
#  ['209235', 'Fremont city, California', '06', '26000'],
#  ['5779', 'French Camp CDP, California', '06', '26028'],
#  ['173', 'French Gulch CDP, California', '06', '26056'],
#  ['21008', 'French Valley CDP, California', '06', '26067'],
#  ['484008', 'Fresno city, California', '06', '27000'],
#  ['462', 'Friant CDP, California', '06', '27014'],
#  ['967', 'Fruitdale CDP, California', '06', '27080'],
#  ['5812', 'Fruitridge Pocket CDP, California', '06', '27130'],
#  ['994', 'Fuller Acres CDP, California', '06', '27190'],
#  ['132872', 'Fullerton city, California', '06', '28000'],
#  ['596', 'Fulton CDP, California', '06', '28014'],
#  ['64', 'Furnace Creek CDP, California', '06', '28021'],
#  ['23074', 'Galt city, California', '06', '28112'],
#  ['644', 'Garberville CDP, California', '06', '28154'],
#  ['58668', 'Gardena city, California', '06', '28168'],
#  ['10471', 'Garden Acres CDP, California', '06', '28182'],
#  ['451', 'Garden Farms CDP, California', '06', '28210'],
#  ['169009', 'Garden Grove city, California', '06', '29000'],
#  ['103', 'Garey CDP, California', '06', '29070'],
#  ['6597', 'Garnet CDP, California', '06', '29112'],
#  ['572', 'Gasquet CDP, California', '06', '29154'],
#  ['170', 'Gazelle CDP, California', '06', '29252'],
#  ['2378', 'Georgetown CDP, California', '06', '29350'],
#  ['929', 'Gerber CDP, California', '06', '29392'],
#  ['993', 'Geyserville CDP, California', '06', '29420'],
#  ['46807', 'Gilroy city, California', '06', '29504'],
#  ['19587', 'Glen Avon CDP, California', '06', '29644'],
#  ['192190', 'Glendale city, California', '06', '30000'],
#  ['49882', 'Glendora city, California', '06', '30014'],
#  ['927', 'Glen Ellen CDP, California', '06', '30028'],
#  ['8574', 'Golden Hills CDP, California', '06', '30282'],
#  ['0', 'Gold Mountain CDP, California', '06', '30339'],
#  ['8339', 'Gold River CDP, California', '06', '30345'],
#  ['29397', 'Goleta city, California', '06', '30378'],
#  ['7959', 'Gonzales city, California', '06', '30392'],
#  ['8112', 'Good Hope CDP, California', '06', '30410'],
#  ['198', 'Goodyears Bar CDP, California', '06', '30420'],
#  ['3214', 'Goshen CDP, California', '06', '30476'],
#  ['911', 'Graeagle CDP, California', '06', '30560'],
#  ['12115', 'Grand Terrace city, California', '06', '30658'],
#  ['599', 'Grangeville CDP, California', '06', '30686'],
#  ['22681', 'Granite Bay CDP, California', '06', '30693'],
#  ['3422', 'Granite Hills CDP, California', '06', '30703'],
#  ['0', 'Graniteville CDP, California', '06', '30714'],
#  ['12765', 'Grass Valley city, California', '06', '30798'],
#  ['1598', 'Graton CDP, California', '06', '30812'],
#  ['1454', 'Grayson CDP, California', '06', '30882'],
#  ['877', 'Greeley Hill CDP, California', '06', '30900'],
#  ['5467', 'Greenacres CDP, California', '06', '30938'],
#  ['1421', 'Green Acres CDP, California', '06', '30944'],
#  ['3996', 'Greenfield CDP, California', '06', '30987'],
#  ['15480', 'Greenfield city, California', '06', '30994'],
#  ['203', 'Greenhorn CDP, California', '06', '31029'],
#  ['1181', 'Green Valley CDP (Los Angeles County), California', '06', '31092'],
#  ['1593', 'Green Valley CDP (Solano County), California', '06', '31099'],
#  ['364', 'Greenview CDP, California', '06', '31134'],
#  ['994', 'Greenville CDP, California', '06', '31162'],
#  ['265', 'Grenada CDP, California', '06', '31246'],
#  ['6449', 'Gridley city, California', '06', '31260'],
#  ['407', 'Grimes CDP, California', '06', '31288'],
#  ['793', 'Grizzly Flats CDP, California', '06', '31302'],
#  ['354', 'Groveland CDP, California', '06', '31372'],
#  ['13137', 'Grover Beach city, California', '06', '31393'],
#  ['6770', 'Guadalupe city, California', '06', '31414'],
#  ['4476', 'Guerneville CDP, California', '06', '31470'],
#  ['192', 'Guinda CDP, California', '06', '31540'],
#  ['5438', 'Gustine city, California', '06', '31568'],
#  ['53639', 'Hacienda Heights CDP, California', '06', '31596'],
#  ['11126', 'Half Moon Bay city, California', '06', '31708'],
#  ['532', 'Hamilton Branch CDP, California', '06', '31883'],
#  ['1875', 'Hamilton City CDP, California', '06', '31890'],
#  ['52315', 'Hanford city, California', '06', '31960'],
#  ['1152', 'Happy Camp CDP, California', '06', '32030'],
#  ['3465', 'Harbison Canyon CDP, California', '06', '32044'],
#  ['93', 'Hardwick CDP, California', '06', '32156'],
#  ['0', 'Hartland CDP, California', '06', '32324'],
#  ['2739', 'Hartley CDP, California', '06', '32340'],
#  ['965', 'Hasley Canyon CDP, California', '06', '32385'],
#  ['216', 'Hat Creek CDP, California', '06', '32408'],
#  ['14328', 'Hawaiian Gardens city, California', '06', '32506'],
#  ['84195', 'Hawthorne city, California', '06', '32548'],
#  ['2055', 'Hayfork CDP, California', '06', '32562'],
#  ['141498', 'Hayward city, California', '06', '33000'],
#  ['11082', 'Healdsburg city, California', '06', '33056'],
#  ['5022', 'Heber CDP, California', '06', '33084'],
#  ['76403', 'Hemet city, California', '06', '33182'],
#  ['990', 'Herald CDP, California', '06', '33294'],
#  ['23061', 'Hercules city, California', '06', '33308'],
#  ['1399', 'Herlong CDP, California', '06', '33336'],
#  ['19355', 'Hermosa Beach city, California', '06', '33364'],
#  ['86405', 'Hesperia city, California', '06', '33434'],
#  ['439', 'Hickman CDP, California', '06', '33504'],
#  ['2522', 'Hidden Hills city, California', '06', '33518'],
#  ['3930', 'Hidden Meadows CDP, California', '06', '33532'],
#  ['6185', 'Hidden Valley Lake CDP, California', '06', '33549'],
#  ['4302', 'Highgrove CDP, California', '06', '33574'],
#  ['52341', 'Highland city, California', '06', '33588'],
#  ['4147', 'Highlands-Baywood Park CDP, California', '06', '33633'],
#  ['10650', 'Hillsborough town, California', '06', '33798'],
#  ['4997', 'Hilmar-Irwin CDP, California', '06', '33861'],
#  ['352', 'Hiouchi CDP, California', '06', '33935'],
#  ['34539', 'Hollister city, California', '06', '34120'],
#  ['5835', 'Holtville city, California', '06', '34246'],
#  ['1916', 'Home Garden CDP, California', '06', '34281'],
#  ['10947', 'Home Gardens CDP, California', '06', '34302'],
#  ['7004', 'Homeland CDP, California', '06', '34316'],
#  ['2888', 'Homestead Valley CDP, California', '06', '34392'],
#  ['109', 'Homewood Canyon CDP, California', '06', '34405'],
#  ['572', 'Honcut CDP, California', '06', '34428'],
#  ['173', 'Hood CDP, California', '06', '34484'],
#  ['874', 'Hopland CDP, California', '06', '34652'],
#  ['270', 'Hornbrook CDP, California', '06', '34694'],
#  ['0', 'Hornitos CDP, California', '06', '34708'],
#  ['6267', 'Hughson city, California', '06', '34904'],
#  ['3769', 'Humboldt Hill CDP, California', '06', '34928'],
#  ['188914', 'Huntington Beach city, California', '06', '36000'],
#  ['58642', 'Huntington Park city, California', '06', '36056'],
#  ['6691', 'Huron city, California', '06', '36084'],
#  ['191', 'Hyampom CDP, California', '06', '36098'],
#  ['1197', 'Hydesville CDP, California', '06', '36126'],
#  ['30', 'Idlewild CDP, California', '06', '36168'],
#  ['2193', 'Idyllwild-Pine Cove CDP, California', '06', '36203'],
#  ['13406', 'Imperial city, California', '06', '36280'],
#  ['26254', 'Imperial Beach city, California', '06', '36294'],
#  ['551', 'Independence CDP, California', '06', '36350'],
#  ['35', 'Indian Falls CDP, California', '06', '36364'],
#  ['1029', 'Indianola CDP, California', '06', '36420'],
#  ['4858', 'Indian Wells city, California', '06', '36434'],
#  ['72486', 'Indio city, California', '06', '36448'],
#  ['1390', 'Indio Hills CDP, California', '06', '36452'],
#  ['368', 'Industry city, California', '06', '36490'],
#  ['110053', 'Inglewood city, California', '06', '36546'],
#  ['6810', 'Interlaken CDP, California', '06', '36613'],
#  ['1380', 'Inverness CDP, California', '06', '36616'],
#  ['1676', 'Inyokern CDP, California', '06', '36658'],
#  ['7845', 'Ione city, California', '06', '36672'],
#  ['273', 'Iron Horse CDP, California', '06', '36735'],
#  ['199117', 'Irvine city, California', '06', '36770'],
#  ['1443', 'Irwindale city, California', '06', '36826'],
#  ['23776', 'Isla Vista CDP, California', '06', '36868'],
#  ['928', 'Isleton city, California', '06', '36882'],
#  ['4315', 'Ivanhoe CDP, California', '06', '36910'],
#  ['4625', 'Jackson city, California', '06', '36980'],
#  ['628', 'Jacumba CDP, California', '06', '37022'],
#  ['3684', 'Jamestown CDP, California', '06', '37106'],
#  ['5319', 'Jamul CDP, California', '06', '37120'],
#  ['1204', 'Janesville CDP, California', '06', '37134'],
#  ['99', 'Jenner CDP, California', '06', '37274'],
#  ...]

# %%
twenty_ten_ca_zip_code_response_list = []
for zip_code in california_zip_codes:
    try:
        base_url = f"https://api.census.gov/data/2010/acs/acs5?key={acs_5yr_key}&get="
        query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{zip_code}&in=state:06"
        twenty_ten_response = requests.get(query_url).json()
        zip_code_df = pd.DataFrame(o_nine_response[1:], columns=df_columns)
        cols = zip_code_df.columns.tolist()
        cols = cols[-2:] + cols[:-2]
        zip_code_df = zip_code_df[cols]
        zip_code_df["year"] = year
        if int(zip_code_df["total_pop"]) > 0:
            zip_code_df["pct_25_34"] = ((int(zip_code_df["total_24_29_female"])
                            + int(zip_code_df["total_30_34_female"]) 
                            + int(zip_code_df["total_24_29_male"])
                            + int(zip_code_df["total_30_34_female"]))
                            / int(zip_code_df["total_pop"])
                           ) * 100
            zip_code_df["pct_college_deg"] = ((int(zip_code_df["with_bachelors"]) 
                                  + int(zip_code_df["with_advanced_deg"]))
                                  / int(zip_code_df["total_pop"])
                                 ) * 100
            zip_code_df["pct_wht"] = (int(zip_code_df["total_wht"]) / int(zip_code_df["total_pop"])) * 100
        else:
            zip_code_df["pct_25_34"] = 0
            zip_code_df["pct_college_deg"] = 0
            zip_code_df["pct_wht"] = 0
        twenty_ten_ca_zip_code_response_list.append(zip_code_df)
    except json.decoder.JSONDecodeError:
        no_response_list.append(zip_code)
        print(zip_code)
        pass
# Out:
# 94102
# 94103
# 94104
# 94105
# 94107
# 94108
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-15465ce1c296> in <module>
#       4         base_url = f"https://api.census.gov/data/2010/acs/acs5?key={acs_5yr_key}&get="
#       5         query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{zip_code}&in=state:06"
# ----> 6         twenty_ten_response = requests.get(query_url).json()
#       7         zip_code_df = pd.DataFrame(o_nine_response[1:], columns=df_columns)
#       8         cols = zip_code_df.columns.tolist()
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %% [markdown]
# ## Querying the ACS 5-year API for demographic data for all zip codes from 2011 - 2017

# %%
total_zip_code_list = []
no_response_list = []
year_list = ["2011", "2012", "2013", "2014", "2015", "2016", "2017"]
for year in year_list:
    print(year)
    for zip_code in all_zip_codes:
        try:
            base_url = f"https://api.census.gov/data/{year}/acs/acs5?get="
            query_url = base_url+f"{variables}&for=zip%20code%20tabulation%20area:{zip_code}&key={acs_5yr_key}"
            zip_code_response = requests.get(query_url).json()
            zip_code_df = pd.DataFrame(zip_code_response[1:], columns=df_columns)
            cols = zip_code_df.columns.tolist()
            cols = cols[-2:] + cols[:-2]
            zip_code_df = zip_code_df[cols]
            zip_code_df["year"] = year
            if int(zip_code_df["total_pop"]) > 0:
                zip_code_df["pct_25_34"] = ((int(zip_code_df["total_24_29_female"])
                            + int(zip_code_df["total_30_34_female"]) 
                            + int(zip_code_df["total_24_29_male"])
                            + int(zip_code_df["total_30_34_female"]))
                            / int(zip_code_df["total_pop"])
                           ) * 100
                zip_code_df["pct_college_deg"] = ((int(zip_code_df["with_bachelors"]) 
                                  + int(zip_code_df["with_advanced_deg"]))
                                  / int(zip_code_df["total_pop"])
                                 ) * 100
                zip_code_df["pct_wht"] = (int(zip_code_df["total_wht"]) / int(zip_code_df["total_pop"])) * 100
            else:
                zip_code_df["pct_25_34"] = 0
                zip_code_df["pct_college_deg"] = 0
                zip_code_df["pct_wht"] = 0
            total_zip_code_list.append(zip_code_df)
        except json.decoder.JSONDecodeError:
            no_response_list.append(zip_code)
            print(zip_code)
            pass
    sleep(240)
# Out:
# 2011
# 98124
# 2012
# 98124
# 2013
# 98124
# 2014
# 98124
# 2015
# 98124
# 2016
# 98124
# 2017
# 98124

# %%
total_zip_code_responses_df = pd.concat(total_zip_code_list, ignore_index=True)

# %%
total_zip_code_responses_df
# Out:
#     with_advanced_deg zip_code total_pop total_24_29_female total_30_34_female total_24_29_male total_30_34_male total_24_29_female_wht total_30_34_female_wht total_24_29_male_wht total_30_34_male_wht total_wht with_bachelors  year  pct_25_34  pct_college_deg    pct_wht
# 0                 278    90001     54760               1971               2193             3144             2000                   1608                   1805                 2353                 1570     40379            912  2011  17.350256         2.173119  73.738130
# 1                3244    90004     63932               2874               2644             2974             3285                   1143                    886                  872                 1249     23007          10144  2011  17.418507        20.941000  35.986673
# 2                1451    90007     42265               1883               1233             2387             1449                    572                    403                  849                  492     14748           2015  2011  15.937537         8.200639  34.894120
# 3                 325    90010      3229                171                125              131              176                     12                     33                    4                   32       713            997  2011  17.095076        40.941468  22.081140
# 4                1610    90012     29298               1328                801             2272             1877                    389                    165                  846                  707      7628           2833  2011  17.755478        15.164858  26.035907
# 5                 611    90013      8216                218                254              411              458                    139                    116                  248                  315      3046           1284  2011  13.838851        23.064752  37.074002
# 6                 356    90014      5204                316                134              327              225                    134                     15                  252                  108      1942            655  2011  17.505765        19.427364  37.317448
# 7                 812    90015     17957                881                742              830             1026                    226                    222                  382                  318      5863           1262  2011  17.792504        11.549813  32.650220
